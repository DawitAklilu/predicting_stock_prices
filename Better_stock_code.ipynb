# %%
# %matplotlib inline

# Start importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model, Sequential 
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU
from tensorflow.keras import optimizers     
from tensorflow.keras import regularizers           
from tensorflow.keras.utils import to_categorical
from timeit import default_timer as timer
rnn = SimpleRNN

# %%
Apple_df = pd.read_csv("AAPL_reversed.csv")
Apple_df.head()
len(Apple_df)
# Out:
# 9715

# %%
def format_data(data, length_of_sequence = 2):  
    """
        Inputs:
            data(a numpy array): the data that will be the inputs to the recurrent neural
                network
            length_of_sequence (an int): the number of elements in one iteration of the
                sequence patter.  For a function approximator use length_of_sequence = 2.
        Returns:
            rnn_input (a 3D numpy array): the input data for the recurrent neural network.  Its
                dimensions are length of data - length of sequence, length of sequence, 
                dimnsion of data
            rnn_output (a numpy array): the training data for the neural network
        Formats data to be used in a recurrent neural network.
    """

    X, Y = [], []
    for i in range(len(data)-length_of_sequence):
        # Get the next length_of_sequence elements
        a = data[i:i+length_of_sequence]
        # Get the element that immediately follows that
        b = data[i+length_of_sequence]
        # Reshape so that each data point is contained in its own array
        a = np.reshape (a, (len(a), 1))
        X.append(a)
        Y.append(b)
    rnn_input = np.array(X)
    rnn_output = np.array(Y)

    return rnn_input, rnn_output

# %%
def rnn(length_of_sequences, batch_size = None, stateful = False):
    """
        Inputs:
            length_of_sequences (an int): the number of y values in "x data".  This is determined
                when the data is formatted
            batch_size (an int): Default value is None.  See Keras documentation of SimpleRNN.
            stateful (a boolean): Default value is False.  See Keras documentation of SimpleRNN.
        Returns:
            model (a Keras model): The recurrent neural network that is built and compiled by this
                method
        Builds and compiles a recurrent neural network with one hidden layer and returns the model.
    """
    # Number of neurons in the input and output layers
    in_out_neurons = 1
    # Number of neurons in the hidden layer
    hidden_neurons = 200
    # Define the input layer
    inp = Input(batch_shape=(batch_size, 
                length_of_sequences, 
                in_out_neurons))  
    # Define the hidden layer as a simple RNN layer with a set number of neurons and add it to 
    # the network immediately after the input layer
    rnn = SimpleRNN(hidden_neurons, 
                    return_sequences=False,
                    stateful = stateful,
                    name="RNN")(inp)
    # Define the output layer as a dense neural network layer (standard neural network layer)
    #and add it to the network immediately after the hidden layer.
    dens = Dense(in_out_neurons,name="dense")(rnn)
    # Create the machine learning model starting with the input layer and ending with the 
    # output layer
    model = Model(inputs=[inp],outputs=[dens])
    # Compile the machine learning model using the mean squared error function as the loss 
    # function and an Adams optimizer.
    model.compile(loss="mean_squared_error", optimizer="adam")  
    return model

# %%
# y_tot = Apple_df.Close.values[:13]
# X_tot = np.arange(1,y_tot.shape[0]+1)
correct_predicted_directions = [] 
# This is the number of points that will be used in as the training data
dim=200 #dim is the number of training points + one extra points to predict 
datatype='VaryDimension'
    #:20 means up ot 20
for index in range(Apple_df.shape[0]):
    start = index
    stop = index + dim  # window size  +1 
    y_tot = Apple_df.Close.values[start:stop]
    print('**',len(y_tot))
    X_tot = np.arange(1,y_tot.shape[0]+1)
    # put code to train model and show results here
    
    def test_rnn (x1, y_test, plot_min, plot_max):
        """
            Inputs:
                x1 (a list or numpy array): The complete x component of the data set
                y_test (a list or numpy array): The complete y component of the data set
                plot_min (an int or float): the smallest x value used in the training data
                plot_max (an int or float): the largest x valye used in the training data
            Returns:
                None.
            Uses a trained recurrent neural network model to predict future points in the 
            series.  Computes the MSE of the predicted data set from the true data set, saves
            the predicted data set to a csv file, and plots the predicted and true data sets w
            while also displaying the data range used for training.
        """
        # Add the training data as the first dim points in the predicted data array as these
        # are known values.
        y_pred = y_test[:dim].tolist()
        # Generate the first input to the trained recurrent neural network using the last two 
        # points of the training data.  Based on how the network was trained this means that it
        # will predict the first point in the data set after the training data.  All of the 
        # brackets are necessary for Tensorflow.
        next_input = np.array([[[y_test[dim-2]], [y_test[dim-1]]]])
        # Save the very last point in the training data set.  This will be used later.
        last = [y_test[dim-1]]

        # Iterate until the complete data set is created.
        for i in range (dim, len(y_test)):
            # Predict the next point in the data set using the previous two points.
            next = model.predict(next_input)
            # Append just the number of the predicted data set
            y_pred.append(next[0][0])
            # Create the input that will be used to predict the next data point in the data set.
            next_input = np.array([[last, next[0]]], dtype=np.float64)
            last = next

        # Print the mean squared error between the known data set and the predicted data set.
        print('MSE: ', np.square(np.subtract(y_test, y_pred)).mean())
        # Save the predicted data set as a csv file for later use
        name = datatype + 'Predicted'+str(dim)+'.csv'
        np.savetxt(name, y_pred, delimiter=',')
        # Plot the known data set and the predicted data set.  The red box represents the region that was used
        # for the training data.
        fig, ax = plt.subplots()
        ax.plot(x1, y_test, label="true", linewidth=3)
        ax.plot(x1, y_pred, 'g-.',label="predicted", linewidth=4)
        ax.legend()
        # Created a red region to represent the points used in the training data.
        ax.axvspan(plot_min, plot_max, alpha=0.25, color='red')
        plt.show()

    # Check to make sure the data set is complete
    assert len(X_tot) == len(y_tot)


    # Separate the training data from the whole data set
    X_train = X_tot[:dim-1] #-1 means it uses all data
    y_train = y_tot[:dim-1]
    print('**',len(y_train))


    # Generate the training data for the RNN, using a sequence of 2
    rnn_input, rnn_training = format_data(y_train, 2)


    # Create a recurrent neural network in Keras and produce a summary of the 
    # machine learning model
    model = rnn(length_of_sequences = rnn_input.shape[1])
    model.summary()

    # Start the timer.  Want to time training+testing
    start = timer()
    # Fit the model using the training data genenerated above using 150 training iterations and a 5%
    # validation split.  Setting verbose to True prints information about each training iteration.
    hist = model.fit(rnn_input, rnn_training, batch_size=None, epochs=40, 
                     verbose=True,validation_split=0.05)

    for label in ["loss","val_loss"]:
        plt.plot(hist.history[label],label=label)

    plt.ylabel("loss")
    plt.xlabel("epoch")
    plt.title("The final validation loss: {}".format(hist.history["val_loss"][-1]))
    plt.legend()
    plt.show()

    # Use the trained neural network to predict more points of the data set
    test_rnn(X_tot, y_tot, X_tot[0], X_tot[dim-1])
    # Stop the timer and calculate the total time needed.
    end = timer()
    print('Time: ', end-start)

    if index == 5:
        break # stops the loop

    
    #:20 means up ot 20
# Out:
# ** 200
# ** 199
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2, 1)]            0
# _________________________________________________________________
# RNN (SimpleRNN)              (None, 200)               40400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 40,601
# Trainable params: 40,601
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 6/6 [==============================] - 3s 259ms/step - loss: 0.0028 - val_loss: 3.0414e-04
# Epoch 2/40
# 6/6 [==============================] - 1s 162ms/step - loss: 3.5492e-04 - val_loss: 2.8864e-05
# Epoch 3/40
# 6/6 [==============================] - 1s 164ms/step - loss: 2.0211e-04 - val_loss: 5.1652e-04
# Epoch 4/40
# 6/6 [==============================] - 0s 75ms/step - loss: 2.2580e-04 - val_loss: 8.8010e-06
# Epoch 5/40
# 6/6 [==============================] - 1s 136ms/step - loss: 1.5815e-04 - val_loss: 6.4353e-05
# Epoch 6/40
# 6/6 [==============================] - 1s 98ms/step - loss: 4.9774e-05 - val_loss: 7.8221e-05
# Epoch 7/40
# 6/6 [==============================] - 1s 188ms/step - loss: 2.8621e-05 - val_loss: 6.5872e-06
# Epoch 8/40
# 6/6 [==============================] - 1s 150ms/step - loss: 3.1112e-05 - val_loss: 6.3403e-05
# Epoch 9/40
# 6/6 [==============================] - 1s 192ms/step - loss: 2.6023e-05 - val_loss: 1.2037e-05
# Epoch 10/40
# 6/6 [==============================] - 1s 153ms/step - loss: 2.3589e-05 - val_loss: 2.1334e-05
# Epoch 11/40
# 6/6 [==============================] - 1s 145ms/step - loss: 1.5587e-05 - val_loss: 2.0139e-05
# Epoch 12/40
# 6/6 [==============================] - 1s 170ms/step - loss: 1.7046e-05 - val_loss: 1.3263e-05
# Epoch 13/40
# 6/6 [==============================] - 2s 289ms/step - loss: 1.5432e-05 - val_loss: 1.5520e-05
# Epoch 14/40
# 6/6 [==============================] - 1s 186ms/step - loss: 1.5609e-05 - val_loss: 9.6117e-06
# Epoch 15/40
# 6/6 [==============================] - 1s 92ms/step - loss: 1.5065e-05 - val_loss: 1.2898e-05
# Epoch 16/40
# 6/6 [==============================] - 1s 94ms/step - loss: 1.7801e-05 - val_loss: 8.8595e-06
# Epoch 17/40
# 6/6 [==============================] - 0s 81ms/step - loss: 1.7659e-05 - val_loss: 1.1422e-05
# Epoch 18/40
# 6/6 [==============================] - 0s 39ms/step - loss: 1.6698e-05 - val_loss: 8.4116e-06
# Epoch 19/40
# 6/6 [==============================] - 0s 40ms/step - loss: 1.5673e-05 - val_loss: 8.2810e-06
# Epoch 20/40
# 6/6 [==============================] - 0s 53ms/step - loss: 1.6774e-05 - val_loss: 8.4994e-06
# Epoch 21/40
# 6/6 [==============================] - 0s 56ms/step - loss: 1.5919e-05 - val_loss: 7.2125e-06
# Epoch 22/40
# 6/6 [==============================] - 0s 43ms/step - loss: 1.8239e-05 - val_loss: 9.3980e-06
# Epoch 23/40
# 6/6 [==============================] - 0s 51ms/step - loss: 1.5615e-05 - val_loss: 6.3098e-06
# Epoch 24/40
# 6/6 [==============================] - 0s 39ms/step - loss: 1.4902e-05 - val_loss: 8.9571e-06
# Epoch 25/40
# 6/6 [==============================] - 0s 53ms/step - loss: 1.5717e-05 - val_loss: 6.5266e-06
# Epoch 26/40
# 6/6 [==============================] - 0s 39ms/step - loss: 1.6759e-05 - val_loss: 8.6245e-06
# Epoch 27/40
# 6/6 [==============================] - 0s 37ms/step - loss: 1.4692e-05 - val_loss: 6.6772e-06
# Epoch 28/40
# 6/6 [==============================] - 0s 66ms/step - loss: 1.6324e-05 - val_loss: 9.3873e-06
# Epoch 29/40
# 6/6 [==============================] - 0s 33ms/step - loss: 1.8801e-05 - val_loss: 6.7233e-06
# Epoch 30/40
# 6/6 [==============================] - 0s 46ms/step - loss: 1.6225e-05 - val_loss: 6.2620e-06
# Epoch 31/40
# 6/6 [==============================] - 0s 27ms/step - loss: 1.6795e-05 - val_loss: 8.8145e-06
# Epoch 32/40
# 6/6 [==============================] - 0s 54ms/step - loss: 1.6817e-05 - val_loss: 7.8910e-06
# Epoch 33/40
# 6/6 [==============================] - 0s 28ms/step - loss: 1.5946e-05 - val_loss: 5.8110e-06
# Epoch 34/40
# 6/6 [==============================] - 1s 100ms/step - loss: 1.6918e-05 - val_loss: 1.5813e-05
# Epoch 35/40
# 6/6 [==============================] - 1s 100ms/step - loss: 1.8223e-05 - val_loss: 5.8654e-06
# Epoch 36/40
# 6/6 [==============================] - 1s 128ms/step - loss: 1.5582e-05 - val_loss: 1.1775e-05
# Epoch 37/40
# 6/6 [==============================] - 1s 164ms/step - loss: 1.6534e-05 - val_loss: 6.4088e-06
# Epoch 38/40
# 6/6 [==============================] - 0s 63ms/step - loss: 1.5375e-05 - val_loss: 6.9690e-06
# Epoch 39/40
# 6/6 [==============================] - 1s 152ms/step - loss: 1.5295e-05 - val_loss: 7.6628e-06
# Epoch 40/40
# 6/6 [==============================] - 1s 112ms/step - loss: 1.3768e-05 - val_loss: 6.0142e-06
# MSE:  0.0
# Time:  26.75397781401989
# ** 200
# ** 199
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 2, 1)]            0
# _________________________________________________________________
# RNN (SimpleRNN)              (None, 200)               40400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 40,601
# Trainable params: 40,601
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 6/6 [==============================] - 3s 218ms/step - loss: 0.0035 - val_loss: 7.4907e-04
# Epoch 2/40
# 6/6 [==============================] - 1s 103ms/step - loss: 4.2117e-04 - val_loss: 1.2377e-04
# Epoch 3/40
# 6/6 [==============================] - 1s 106ms/step - loss: 4.1572e-04 - val_loss: 5.1230e-04
# Epoch 4/40
# 6/6 [==============================] - 0s 85ms/step - loss: 3.0210e-04 - val_loss: 2.4198e-05
# Epoch 5/40
# 6/6 [==============================] - 1s 107ms/step - loss: 8.6610e-05 - val_loss: 4.6289e-06
# Epoch 6/40
# 6/6 [==============================] - 1s 136ms/step - loss: 5.4392e-05 - val_loss: 1.4339e-04
# Epoch 7/40
# 6/6 [==============================] - 1s 222ms/step - loss: 6.8879e-05 - val_loss: 1.1181e-05
# Epoch 8/40
# 6/6 [==============================] - 1s 72ms/step - loss: 3.2414e-05 - val_loss: 1.4652e-05
# Epoch 9/40
# 6/6 [==============================] - 0s 66ms/step - loss: 2.1950e-05 - val_loss: 4.2111e-05
# Epoch 10/40
# 6/6 [==============================] - 1s 125ms/step - loss: 1.9310e-05 - val_loss: 7.9798e-06
# Epoch 11/40
# 6/6 [==============================] - 1s 118ms/step - loss: 1.8578e-05 - val_loss: 2.1416e-05
# Epoch 12/40
# 6/6 [==============================] - 1s 95ms/step - loss: 1.7596e-05 - val_loss: 1.0685e-05
# Epoch 13/40
# 6/6 [==============================] - 1s 184ms/step - loss: 1.4975e-05 - val_loss: 1.1630e-05
# Epoch 14/40
# 6/6 [==============================] - 0s 79ms/step - loss: 1.5355e-05 - val_loss: 1.0607e-05
# Epoch 15/40
# 6/6 [==============================] - 1s 148ms/step - loss: 1.5161e-05 - val_loss: 7.6374e-06
# Epoch 16/40
# 6/6 [==============================] - 1s 99ms/step - loss: 1.4576e-05 - val_loss: 9.1850e-06
# Epoch 17/40
# 6/6 [==============================] - 1s 154ms/step - loss: 1.4560e-05 - val_loss: 7.4746e-06
# Epoch 18/40
# 6/6 [==============================] - 1s 158ms/step - loss: 1.4513e-05 - val_loss: 7.1371e-06
# Epoch 19/40
# 6/6 [==============================] - 1s 120ms/step - loss: 1.4919e-05 - val_loss: 7.8570e-06
# Epoch 20/40
# 6/6 [==============================] - 1s 170ms/step - loss: 1.6592e-05 - val_loss: 6.6975e-06
# Epoch 21/40
# 6/6 [==============================] - 1s 118ms/step - loss: 1.6683e-05 - val_loss: 7.1639e-06
# Epoch 22/40
# 6/6 [==============================] - 1s 102ms/step - loss: 1.3505e-05 - val_loss: 6.5439e-06
# Epoch 23/40
# 6/6 [==============================] - 1s 155ms/step - loss: 1.6951e-05 - val_loss: 6.6560e-06
# Epoch 24/40
# 6/6 [==============================] - 1s 176ms/step - loss: 1.3221e-05 - val_loss: 6.1377e-06
# Epoch 25/40
# 6/6 [==============================] - 1s 114ms/step - loss: 1.5114e-05 - val_loss: 8.1248e-06
# Epoch 26/40
# 6/6 [==============================] - 0s 79ms/step - loss: 1.4590e-05 - val_loss: 5.9117e-06
# Epoch 27/40
# 6/6 [==============================] - 1s 149ms/step - loss: 1.4845e-05 - val_loss: 6.6545e-06
# Epoch 28/40
# 6/6 [==============================] - 2s 301ms/step - loss: 1.5557e-05 - val_loss: 6.6382e-06
# Epoch 29/40
# 6/6 [==============================] - 1s 170ms/step - loss: 1.5634e-05 - val_loss: 6.3882e-06
# Epoch 30/40
# 6/6 [==============================] - 1s 195ms/step - loss: 1.3620e-05 - val_loss: 6.0273e-06
# Epoch 31/40
# 6/6 [==============================] - 1s 145ms/step - loss: 1.5076e-05 - val_loss: 7.1351e-06
# Epoch 32/40
# 6/6 [==============================] - 1s 124ms/step - loss: 1.5836e-05 - val_loss: 5.7761e-06
# Epoch 33/40
# 6/6 [==============================] - 0s 90ms/step - loss: 1.5404e-05 - val_loss: 9.0923e-06
# Epoch 34/40
# 6/6 [==============================] - 0s 39ms/step - loss: 1.5804e-05 - val_loss: 5.7830e-06
# Epoch 35/40
# 6/6 [==============================] - 0s 65ms/step - loss: 1.4690e-05 - val_loss: 7.1943e-06
# Epoch 36/40
# 6/6 [==============================] - 1s 97ms/step - loss: 1.3299e-05 - val_loss: 5.9725e-06
# Epoch 37/40
# 6/6 [==============================] - 0s 64ms/step - loss: 1.2955e-05 - val_loss: 6.8884e-06
# Epoch 38/40
# 6/6 [==============================] - 1s 155ms/step - loss: 1.4449e-05 - val_loss: 6.2535e-06
# Epoch 39/40
# 6/6 [==============================] - 1s 135ms/step - loss: 1.4229e-05 - val_loss: 6.8220e-06
# Epoch 40/40
# 6/6 [==============================] - 1s 91ms/step - loss: 1.5942e-05 - val_loss: 6.0240e-06
# MSE:  0.0
# Time:  32.694152646989096
# ** 200
# ** 199
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 2, 1)]            0
# _________________________________________________________________
# RNN (SimpleRNN)              (None, 200)               40400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 40,601
# Trainable params: 40,601
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 6/6 [==============================] - 3s 213ms/step - loss: 0.0051 - val_loss: 0.0023
# Epoch 2/40
# 6/6 [==============================] - 1s 136ms/step - loss: 9.9833e-04 - val_loss: 2.3724e-04
# Epoch 3/40
# 6/6 [==============================] - 1s 124ms/step - loss: 8.4005e-04 - val_loss: 1.1877e-04
# Epoch 4/40
# 6/6 [==============================] - 1s 100ms/step - loss: 1.5515e-04 - val_loss: 4.4007e-04
# Epoch 5/40
# 6/6 [==============================] - 1s 112ms/step - loss: 1.5266e-04 - val_loss: 8.1911e-06
# Epoch 6/40
# 6/6 [==============================] - 0s 81ms/step - loss: 1.3405e-04 - val_loss: 2.6187e-05
# Epoch 7/40
# 6/6 [==============================] - 1s 189ms/step - loss: 3.6320e-05 - val_loss: 1.3680e-04
# Epoch 8/40
# 6/6 [==============================] - 1s 101ms/step - loss: 6.0150e-05 - val_loss: 2.1310e-05
# Epoch 9/40
# 6/6 [==============================] - 1s 142ms/step - loss: 3.1683e-05 - val_loss: 2.3724e-05
# Epoch 10/40
# 6/6 [==============================] - 0s 26ms/step - loss: 2.0339e-05 - val_loss: 4.6003e-05
# Epoch 11/40
# 6/6 [==============================] - 1s 124ms/step - loss: 2.1564e-05 - val_loss: 1.9754e-05
# Epoch 12/40
# 6/6 [==============================] - 1s 92ms/step - loss: 2.0208e-05 - val_loss: 1.8738e-05
# Epoch 13/40
# 6/6 [==============================] - 1s 65ms/step - loss: 1.9242e-05 - val_loss: 2.4130e-05
# Epoch 14/40
# 6/6 [==============================] - 0s 30ms/step - loss: 2.1146e-05 - val_loss: 1.2941e-05
# Epoch 15/40
# 6/6 [==============================] - 1s 141ms/step - loss: 1.9382e-05 - val_loss: 1.6594e-05
# Epoch 16/40
# 6/6 [==============================] - 0s 63ms/step - loss: 1.7713e-05 - val_loss: 1.3286e-05
# Epoch 17/40
# 6/6 [==============================] - 1s 127ms/step - loss: 1.7498e-05 - val_loss: 1.2729e-05
# Epoch 18/40
# 6/6 [==============================] - 1s 116ms/step - loss: 1.8316e-05 - val_loss: 1.0951e-05
# Epoch 19/40
# 6/6 [==============================] - 1s 99ms/step - loss: 1.6517e-05 - val_loss: 1.0453e-05
# Epoch 20/40
# 6/6 [==============================] - 0s 72ms/step - loss: 1.7855e-05 - val_loss: 1.1096e-05
# Epoch 21/40
# 6/6 [==============================] - 0s 67ms/step - loss: 1.9376e-05 - val_loss: 9.6385e-06
# Epoch 22/40
# 6/6 [==============================] - 0s 76ms/step - loss: 1.6028e-05 - val_loss: 1.0521e-05
# Epoch 23/40
# 6/6 [==============================] - 1s 106ms/step - loss: 1.7276e-05 - val_loss: 9.1282e-06
# Epoch 24/40
# 6/6 [==============================] - 1s 132ms/step - loss: 1.7436e-05 - val_loss: 9.7148e-06
# Epoch 25/40
# 6/6 [==============================] - 2s 274ms/step - loss: 1.7932e-05 - val_loss: 9.0813e-06
# Epoch 26/40
# 6/6 [==============================] - 1s 115ms/step - loss: 1.5540e-05 - val_loss: 9.6535e-06
# Epoch 27/40
# 6/6 [==============================] - 1s 115ms/step - loss: 1.8953e-05 - val_loss: 9.0843e-06
# Epoch 28/40
# 6/6 [==============================] - 1s 209ms/step - loss: 1.5610e-05 - val_loss: 9.1101e-06
# Epoch 29/40
# 6/6 [==============================] - 1s 171ms/step - loss: 1.3622e-05 - val_loss: 9.0833e-06
# Epoch 30/40
# 6/6 [==============================] - 1s 171ms/step - loss: 2.0167e-05 - val_loss: 9.1196e-06
# Epoch 31/40
# 6/6 [==============================] - 1s 121ms/step - loss: 1.6139e-05 - val_loss: 9.1271e-06
# Epoch 32/40
# 6/6 [==============================] - 1s 225ms/step - loss: 1.8616e-05 - val_loss: 9.1603e-06
# Epoch 33/40
# 6/6 [==============================] - 1s 90ms/step - loss: 1.5887e-05 - val_loss: 9.3327e-06
# Epoch 34/40
# 6/6 [==============================] - 1s 102ms/step - loss: 1.6221e-05 - val_loss: 9.4731e-06
# Epoch 35/40
# 6/6 [==============================] - 0s 77ms/step - loss: 1.9079e-05 - val_loss: 9.3230e-06
# Epoch 36/40
# 6/6 [==============================] - 1s 128ms/step - loss: 1.6797e-05 - val_loss: 9.0279e-06
# Epoch 37/40
# 6/6 [==============================] - 1s 122ms/step - loss: 1.6161e-05 - val_loss: 9.0151e-06
# Epoch 38/40
# 6/6 [==============================] - 1s 105ms/step - loss: 1.5659e-05 - val_loss: 9.0855e-06
# Epoch 39/40
# 6/6 [==============================] - 0s 80ms/step - loss: 1.6638e-05 - val_loss: 8.9927e-06
# Epoch 40/40
# 6/6 [==============================] - 0s 52ms/step - loss: 1.5747e-05 - val_loss: 8.9762e-06
# MSE:  0.0
# Time:  30.06368036099593
# ** 200
# ** 199
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 2, 1)]            0
# _________________________________________________________________
# RNN (SimpleRNN)              (None, 200)               40400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 40,601
# Trainable params: 40,601
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 6/6 [==============================] - 3s 220ms/step - loss: 0.0030 - val_loss: 3.5517e-04
# Epoch 2/40
# 6/6 [==============================] - 1s 135ms/step - loss: 3.5359e-04 - val_loss: 5.7322e-05
# Epoch 3/40
# 6/6 [==============================] - 1s 124ms/step - loss: 2.3524e-04 - val_loss: 4.9586e-04
# Epoch 4/40
# 6/6 [==============================] - 1s 109ms/step - loss: 2.3391e-04 - val_loss: 1.3284e-05
# Epoch 5/40
# 6/6 [==============================] - 1s 100ms/step - loss: 1.4312e-04 - val_loss: 4.3013e-05
# Epoch 6/40
# 6/6 [==============================] - 0s 69ms/step - loss: 4.3563e-05 - val_loss: 7.6903e-05
# Epoch 7/40
# 6/6 [==============================] - 1s 127ms/step - loss: 2.6043e-05 - val_loss: 8.1035e-06
# Epoch 8/40
# 6/6 [==============================] - 1s 226ms/step - loss: 2.9476e-05 - val_loss: 5.1244e-05
# Epoch 9/40
# 6/6 [==============================] - 1s 107ms/step - loss: 2.6287e-05 - val_loss: 1.1879e-05
# Epoch 10/40
# 6/6 [==============================] - 1s 142ms/step - loss: 1.8920e-05 - val_loss: 1.2699e-05
# Epoch 11/40
# 6/6 [==============================] - 1s 108ms/step - loss: 1.4596e-05 - val_loss: 1.7105e-05
# Epoch 12/40
# 6/6 [==============================] - 0s 56ms/step - loss: 1.9418e-05 - val_loss: 9.1641e-06
# Epoch 13/40
# 6/6 [==============================] - 0s 53ms/step - loss: 1.5418e-05 - val_loss: 1.2698e-05
# Epoch 14/40
# 6/6 [==============================] - 0s 80ms/step - loss: 1.2212e-05 - val_loss: 8.2295e-06
# Epoch 15/40
# 6/6 [==============================] - 0s 40ms/step - loss: 1.3469e-05 - val_loss: 1.0593e-05
# Epoch 16/40
# 6/6 [==============================] - 1s 123ms/step - loss: 1.2949e-05 - val_loss: 8.1334e-06
# Epoch 17/40
# 6/6 [==============================] - 0s 80ms/step - loss: 1.2969e-05 - val_loss: 8.7513e-06
# Epoch 18/40
# 6/6 [==============================] - 1s 118ms/step - loss: 1.2870e-05 - val_loss: 8.3867e-06
# Epoch 19/40
# 6/6 [==============================] - 1s 141ms/step - loss: 1.3470e-05 - val_loss: 8.2259e-06
# Epoch 20/40
# 6/6 [==============================] - 1s 162ms/step - loss: 1.2205e-05 - val_loss: 8.3165e-06
# Epoch 21/40
# 6/6 [==============================] - 1s 214ms/step - loss: 1.2786e-05 - val_loss: 8.1397e-06
# Epoch 22/40
# 6/6 [==============================] - 1s 156ms/step - loss: 1.2219e-05 - val_loss: 9.1078e-06
# Epoch 23/40
# 6/6 [==============================] - 1s 143ms/step - loss: 1.2182e-05 - val_loss: 8.1257e-06
# Epoch 24/40
# 6/6 [==============================] - 1s 110ms/step - loss: 1.1771e-05 - val_loss: 9.1303e-06
# Epoch 25/40
# 6/6 [==============================] - 1s 114ms/step - loss: 1.1449e-05 - val_loss: 8.1163e-06
# Epoch 26/40
# 6/6 [==============================] - 1s 112ms/step - loss: 1.2969e-05 - val_loss: 1.0119e-05
# Epoch 27/40
# 6/6 [==============================] - 1s 88ms/step - loss: 1.2815e-05 - val_loss: 8.2951e-06
# Epoch 28/40
# 6/6 [==============================] - 0s 73ms/step - loss: 1.2553e-05 - val_loss: 8.6144e-06
# Epoch 29/40
# 6/6 [==============================] - 1s 173ms/step - loss: 1.3294e-05 - val_loss: 8.3331e-06
# Epoch 30/40
# 6/6 [==============================] - 1s 134ms/step - loss: 1.1674e-05 - val_loss: 9.2097e-06
# Epoch 31/40
# 6/6 [==============================] - 1s 143ms/step - loss: 1.3820e-05 - val_loss: 8.7727e-06
# Epoch 32/40
# 6/6 [==============================] - 1s 170ms/step - loss: 1.2092e-05 - val_loss: 8.2230e-06
# Epoch 33/40
# 6/6 [==============================] - 1s 189ms/step - loss: 1.2180e-05 - val_loss: 8.7546e-06
# Epoch 34/40
# 6/6 [==============================] - 0s 70ms/step - loss: 1.1471e-05 - val_loss: 8.1766e-06
# Epoch 35/40
# 6/6 [==============================] - 1s 101ms/step - loss: 1.2373e-05 - val_loss: 8.6019e-06
# Epoch 36/40
# 6/6 [==============================] - 1s 104ms/step - loss: 1.3063e-05 - val_loss: 8.3331e-06
# Epoch 37/40
# 6/6 [==============================] - 1s 186ms/step - loss: 1.2566e-05 - val_loss: 8.3405e-06
# Epoch 38/40
# 6/6 [==============================] - 1s 129ms/step - loss: 1.1650e-05 - val_loss: 8.1608e-06
# Epoch 39/40
# 6/6 [==============================] - 1s 92ms/step - loss: 1.1114e-05 - val_loss: 8.1894e-06
# Epoch 40/40
# 6/6 [==============================] - 0s 67ms/step - loss: 1.1108e-05 - val_loss: 8.0606e-06
# MSE:  0.0
# Time:  31.000105421000626
# ** 200
# ** 199
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 2, 1)]            0
# _________________________________________________________________
# RNN (SimpleRNN)              (None, 200)               40400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 40,601
# Trainable params: 40,601
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 6/6 [==============================] - 3s 235ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 2/40
# 6/6 [==============================] - 1s 144ms/step - loss: 6.9738e-04 - val_loss: 2.4735e-04
# Epoch 3/40
# 6/6 [==============================] - 1s 141ms/step - loss: 6.7434e-04 - val_loss: 5.0763e-04
# Epoch 4/40
# 6/6 [==============================] - 1s 159ms/step - loss: 3.5040e-04 - val_loss: 1.1438e-04
# Epoch 5/40
# 6/6 [==============================] - 1s 156ms/step - loss: 7.6841e-05 - val_loss: 1.6711e-05
# Epoch 6/40
# 6/6 [==============================] - 0s 56ms/step - loss: 1.0308e-04 - val_loss: 1.5067e-04
# Epoch 7/40
# 6/6 [==============================] - 1s 96ms/step - loss: 7.4002e-05 - val_loss: 3.9361e-05
# Epoch 8/40
# 6/6 [==============================] - 0s 86ms/step - loss: 3.3146e-05 - val_loss: 1.2763e-05
# Epoch 9/40
# 6/6 [==============================] - 1s 77ms/step - loss: 3.1676e-05 - val_loss: 5.5879e-05
# Epoch 10/40
# 6/6 [==============================] - 1s 105ms/step - loss: 3.1443e-05 - val_loss: 1.5099e-05
# Epoch 11/40
# 6/6 [==============================] - 1s 109ms/step - loss: 2.0665e-05 - val_loss: 1.6696e-05
# Epoch 12/40
# 6/6 [==============================] - 1s 119ms/step - loss: 1.8778e-05 - val_loss: 1.7961e-05
# Epoch 13/40
# 6/6 [==============================] - 0s 83ms/step - loss: 1.8439e-05 - val_loss: 1.1561e-05
# Epoch 14/40
# 6/6 [==============================] - 0s 87ms/step - loss: 1.7236e-05 - val_loss: 1.4157e-05
# Epoch 15/40
# 6/6 [==============================] - 0s 93ms/step - loss: 1.9113e-05 - val_loss: 1.0532e-05
# Epoch 16/40
# 6/6 [==============================] - 1s 105ms/step - loss: 1.7637e-05 - val_loss: 1.1468e-05
# Epoch 17/40
# 6/6 [==============================] - 0s 37ms/step - loss: 1.7439e-05 - val_loss: 1.0444e-05
# Epoch 18/40
# 6/6 [==============================] - 0s 40ms/step - loss: 1.6648e-05 - val_loss: 1.0428e-05
# Epoch 19/40
# 6/6 [==============================] - 1s 79ms/step - loss: 1.4270e-05 - val_loss: 1.0611e-05
# Epoch 20/40
# 6/6 [==============================] - 1s 114ms/step - loss: 1.5931e-05 - val_loss: 1.0494e-05
# Epoch 21/40
# 6/6 [==============================] - 0s 54ms/step - loss: 1.4618e-05 - val_loss: 1.0672e-05
# Epoch 22/40
# 6/6 [==============================] - 1s 99ms/step - loss: 1.6299e-05 - val_loss: 1.1452e-05
# Epoch 23/40
# 6/6 [==============================] - 1s 99ms/step - loss: 1.5780e-05 - val_loss: 1.0908e-05
# Epoch 24/40
# 6/6 [==============================] - 1s 143ms/step - loss: 1.5722e-05 - val_loss: 1.1185e-05
# Epoch 25/40
# 6/6 [==============================] - 1s 73ms/step - loss: 1.5105e-05 - val_loss: 1.1526e-05
# Epoch 26/40
# 6/6 [==============================] - 1s 140ms/step - loss: 1.5316e-05 - val_loss: 1.2176e-05
# Epoch 27/40
# 6/6 [==============================] - 1s 110ms/step - loss: 1.5048e-05 - val_loss: 1.2176e-05
# Epoch 28/40
# 6/6 [==============================] - 1s 92ms/step - loss: 1.5324e-05 - val_loss: 1.1262e-05
# Epoch 29/40
# 6/6 [==============================] - 1s 80ms/step - loss: 1.5911e-05 - val_loss: 1.1931e-05
# Epoch 30/40
# 6/6 [==============================] - 1s 123ms/step - loss: 1.6594e-05 - val_loss: 1.0874e-05
# Epoch 31/40
# 6/6 [==============================] - 0s 58ms/step - loss: 1.7005e-05 - val_loss: 1.4556e-05
# Epoch 32/40
# 6/6 [==============================] - 0s 79ms/step - loss: 1.7739e-05 - val_loss: 1.0298e-05
# Epoch 33/40
# 6/6 [==============================] - 1s 128ms/step - loss: 1.3191e-05 - val_loss: 1.4501e-05
# Epoch 34/40
# 6/6 [==============================] - 0s 74ms/step - loss: 1.8586e-05 - val_loss: 1.0179e-05
# Epoch 35/40
# 6/6 [==============================] - 0s 78ms/step - loss: 1.9240e-05 - val_loss: 1.1835e-05
# Epoch 36/40
# 6/6 [==============================] - 1s 121ms/step - loss: 1.5080e-05 - val_loss: 1.0873e-05
# Epoch 37/40
# 6/6 [==============================] - 0s 61ms/step - loss: 1.5148e-05 - val_loss: 1.2230e-05
# Epoch 38/40
# 6/6 [==============================] - 0s 39ms/step - loss: 1.6287e-05 - val_loss: 1.3231e-05
# Epoch 39/40
# 6/6 [==============================] - 1s 117ms/step - loss: 1.4638e-05 - val_loss: 1.0872e-05
# Epoch 40/40
# 6/6 [==============================] - 1s 147ms/step - loss: 1.6477e-05 - val_loss: 1.1328e-05
# MSE:  0.0
# Time:  25.712112624023575
# ** 200
# ** 199
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 2, 1)]            0
# _________________________________________________________________
# RNN (SimpleRNN)              (None, 200)               40400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 40,601
# Trainable params: 40,601
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 6/6 [==============================] - 3s 227ms/step - loss: 0.0031 - val_loss: 5.3180e-04
# Epoch 2/40
# 6/6 [==============================] - 1s 96ms/step - loss: 3.7977e-04 - val_loss: 1.5828e-04
# Epoch 3/40
# 6/6 [==============================] - 1s 120ms/step - loss: 3.4316e-04 - val_loss: 4.4171e-04
# Epoch 4/40
# 6/6 [==============================] - 1s 106ms/step - loss: 2.9197e-04 - val_loss: 1.1172e-05
# Epoch 5/40
# 6/6 [==============================] - 1s 111ms/step - loss: 1.2433e-04 - val_loss: 8.9648e-06
# Epoch 6/40
# 6/6 [==============================] - 1s 160ms/step - loss: 3.8735e-05 - val_loss: 7.5228e-05
# Epoch 7/40
# 6/6 [==============================] - 1s 108ms/step - loss: 5.1089e-05 - val_loss: 1.0900e-05
# Epoch 8/40
# 6/6 [==============================] - 1s 123ms/step - loss: 4.0777e-05 - val_loss: 1.0322e-05
# Epoch 9/40
# 6/6 [==============================] - 1s 120ms/step - loss: 2.3555e-05 - val_loss: 1.1859e-05
# Epoch 10/40
# 6/6 [==============================] - 1s 160ms/step - loss: 1.8001e-05 - val_loss: 1.0125e-05
# Epoch 11/40
# 6/6 [==============================] - 1s 68ms/step - loss: 2.2277e-05 - val_loss: 8.6921e-06
# Epoch 12/40
# 6/6 [==============================] - 0s 88ms/step - loss: 1.9105e-05 - val_loss: 8.7485e-06
# Epoch 13/40
# 6/6 [==============================] - 1s 153ms/step - loss: 1.7074e-05 - val_loss: 8.2097e-06
# Epoch 14/40
# 6/6 [==============================] - 1s 116ms/step - loss: 1.8056e-05 - val_loss: 8.0986e-06
# Epoch 15/40
# 6/6 [==============================] - 1s 113ms/step - loss: 1.8999e-05 - val_loss: 1.0353e-05
# Epoch 16/40
# 6/6 [==============================] - 1s 99ms/step - loss: 1.7340e-05 - val_loss: 8.6794e-06
# Epoch 17/40
# 6/6 [==============================] - 0s 69ms/step - loss: 1.6830e-05 - val_loss: 1.0862e-05
# Epoch 18/40
# 6/6 [==============================] - 1s 88ms/step - loss: 1.4809e-05 - val_loss: 9.7058e-06
# Epoch 19/40
# 6/6 [==============================] - 1s 113ms/step - loss: 1.5799e-05 - val_loss: 1.1758e-05
# Epoch 20/40
# 6/6 [==============================] - 0s 59ms/step - loss: 1.7171e-05 - val_loss: 1.0019e-05
# Epoch 21/40
# 6/6 [==============================] - 1s 155ms/step - loss: 1.7364e-05 - val_loss: 1.3347e-05
# Epoch 22/40
# 6/6 [==============================] - 1s 115ms/step - loss: 1.7165e-05 - val_loss: 1.1039e-05
# Epoch 23/40
# 6/6 [==============================] - 1s 149ms/step - loss: 1.6323e-05 - val_loss: 1.1661e-05
# Epoch 24/40
# 6/6 [==============================] - 1s 135ms/step - loss: 1.7353e-05 - val_loss: 1.1616e-05
# Epoch 25/40
# 6/6 [==============================] - 1s 174ms/step - loss: 1.7925e-05 - val_loss: 1.0803e-05
# Epoch 26/40
# 6/6 [==============================] - 1s 223ms/step - loss: 1.6058e-05 - val_loss: 1.5898e-05
# Epoch 27/40
# 6/6 [==============================] - 1s 263ms/step - loss: 1.7835e-05 - val_loss: 9.7396e-06
# Epoch 28/40
# 6/6 [==============================] - 0s 55ms/step - loss: 2.1018e-05 - val_loss: 1.3362e-05
# Epoch 29/40
# 6/6 [==============================] - 0s 81ms/step - loss: 1.7656e-05 - val_loss: 1.2120e-05
# Epoch 30/40
# 6/6 [==============================] - 0s 50ms/step - loss: 1.6642e-05 - val_loss: 1.1339e-05
# Epoch 31/40
# 6/6 [==============================] - 0s 68ms/step - loss: 1.9388e-05 - val_loss: 1.1168e-05
# Epoch 32/40
# 6/6 [==============================] - 1s 109ms/step - loss: 1.5861e-05 - val_loss: 1.2822e-05
# Epoch 33/40
# 6/6 [==============================] - 1s 201ms/step - loss: 1.6242e-05 - val_loss: 1.2296e-05
# Epoch 34/40
# 6/6 [==============================] - 1s 144ms/step - loss: 1.8156e-05 - val_loss: 9.6976e-06
# Epoch 35/40
# 6/6 [==============================] - 1s 161ms/step - loss: 1.7767e-05 - val_loss: 1.7648e-05
# Epoch 36/40
# 6/6 [==============================] - 1s 135ms/step - loss: 1.9285e-05 - val_loss: 7.3388e-06
# Epoch 37/40
# 6/6 [==============================] - 1s 103ms/step - loss: 1.7692e-05 - val_loss: 1.8619e-05
# Epoch 38/40
# 6/6 [==============================] - 1s 98ms/step - loss: 1.9861e-05 - val_loss: 7.0076e-06
# Epoch 39/40
# 6/6 [==============================] - 1s 123ms/step - loss: 1.9175e-05 - val_loss: 2.0421e-05
# Epoch 40/40
# 6/6 [==============================] - 0s 72ms/step - loss: 2.0292e-05 - val_loss: 1.0494e-05
# MSE:  0.0
# Time:  30.239574128005188

# %%
def rnn_2layers(length_of_sequences, batch_size = None, stateful = False):
    """
        Inputs:
            length_of_sequences (an int): the number of y values in "x data".  This is determined
                when the data is formatted
            batch_size (an int): Default value is None.  See Keras documentation of SimpleRNN.
            stateful (a boolean): Default value is False.  See Keras documentation of SimpleRNN.
        Returns:
            model (a Keras model): The recurrent neural network that is built and compiled by this
                method
        Builds and compiles a recurrent neural network with two hidden layers and returns the model.
    """
    # Number of neurons in the input and output layers
    in_out_neurons = 1
    # Number of neurons in the hidden layer, increased from the first network
    hidden_neurons = 500
    # Define the input layer
    inp = Input(batch_shape=(batch_size, 
                length_of_sequences, 
                in_out_neurons))  
    # Create two hidden layers instead of one hidden layer.  Explicitly set the activation
    # function to be the sigmoid function (the default value is hyperbolic tangent)
    rnn1 = SimpleRNN(hidden_neurons, 
                    return_sequences=True,  # This needs to be True if another hidden layer is to follow
                    stateful = stateful, activation = 'sigmoid',
                    name="RNN1")(inp)
    rnn2 = SimpleRNN(hidden_neurons, 
                    return_sequences=False, activation = 'sigmoid',
                    stateful = stateful,
                    name="RNN2")(rnn1)
    # Define the output layer as a dense neural network layer (standard neural network layer)
    #and add it to the network immediately after the hidden layer.
    dens = Dense(in_out_neurons,name="dense")(rnn2)
    # Create the machine learning model starting with the input layer and ending with the 
    # output layer
    model = Model(inputs=[inp],outputs=[dens])
    # Compile the machine learning model using the mean squared error function as the loss 
    # function and an Adams optimizer.
    model.compile(loss="mean_squared_error", optimizer="adam")  
    return model

# Check to make sure the data set is complete
assert len(X_tot) == len(y_tot)

# This is the number of points that will be used in as the training data
dim=12

# Separate the training data from the whole data set
X_train = X_tot[:dim]
y_train = y_tot[:dim]


# Generate the training data for the RNN, using a sequence of 2
rnn_input, rnn_training = format_data(y_train, 2)


# Create a recurrent neural network in Keras and produce a summary of the 
# machine learning model
model = rnn_2layers(length_of_sequences = 2)
model.summary()

# Start the timer.  Want to time training+testing
start = timer()
# Fit the model using the training data genenerated above using 150 training iterations and a 5%
# validation split.  Setting verbose to True prints information about each training iteration.
hist = model.fit(rnn_input, rnn_training, batch_size=None, epochs=150, 
                 verbose=True,validation_split=0.05)


# This section plots the training loss and the validation loss as a function of training iteration.
# This is not required for analyzing the couple cluster data but can help determine if the network is
# being overtrained.
for label in ["loss","val_loss"]:
    plt.plot(hist.history[label],label=label)

plt.ylabel("loss")
plt.xlabel("epoch")
plt.title("The final validation loss: {}".format(hist.history["val_loss"][-1]))
plt.legend()
plt.show()

# Use the trained neural network to predict more points of the data set
test_rnn(X_tot, y_tot, X_tot[0], X_tot[dim-1])
# Stop the timer and calculate the total time needed.
end = timer()
print('Time: ', end-start)
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 2, 1)]            0
# _________________________________________________________________
# RNN1 (SimpleRNN)             (None, 2, 500)            251000
# _________________________________________________________________
# RNN2 (SimpleRNN)             (None, 500)               500500
# _________________________________________________________________
# dense (Dense)                (None, 1)                 501
# =================================================================
# Total params: 752,001
# Trainable params: 752,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 1/1 [==============================] - 4s 4s/step - loss: 2.7111 - val_loss: 4.1440
# Epoch 2/150
# 1/1 [==============================] - 0s 476ms/step - loss: 4.1733 - val_loss: 2.2425
# Epoch 3/150
# 1/1 [==============================] - 0s 481ms/step - loss: 2.2641 - val_loss: 0.0093
# Epoch 4/150
# 1/1 [==============================] - 0s 489ms/step - loss: 0.0107 - val_loss: 1.1360
# Epoch 5/150
# 1/1 [==============================] - 0s 450ms/step - loss: 1.1208 - val_loss: 1.9227
# Epoch 6/150
# 1/1 [==============================] - 0s 472ms/step - loss: 1.9029 - val_loss: 1.0173
# Epoch 7/150
# 1/1 [==============================] - 0s 270ms/step - loss: 1.0029 - val_loss: 0.0922
# Epoch 8/150
# 1/1 [==============================] - 1s 814ms/step - loss: 0.0879 - val_loss: 0.1578
# Epoch 9/150
# 1/1 [==============================] - 1s 559ms/step - loss: 0.1636 - val_loss: 0.7209
# Epoch 10/150
# 1/1 [==============================] - 0s 376ms/step - loss: 0.7331 - val_loss: 0.9062
# Epoch 11/150
# 1/1 [==============================] - 1s 657ms/step - loss: 0.9199 - val_loss: 0.5591
# Epoch 12/150
# 1/1 [==============================] - 0s 244ms/step - loss: 0.5699 - val_loss: 0.1238
# Epoch 13/150
# 1/1 [==============================] - 0s 480ms/step - loss: 0.1289 - val_loss: 0.0095
# Epoch 14/150
# 1/1 [==============================] - 0s 333ms/step - loss: 0.0081 - val_loss: 0.2195
# Epoch 15/150
# 1/1 [==============================] - 1s 597ms/step - loss: 0.2129 - val_loss: 0.4475
# Epoch 16/150
# 1/1 [==============================] - 0s 295ms/step - loss: 0.4379 - val_loss: 0.4463
# Epoch 17/150
# 1/1 [==============================] - 0s 317ms/step - loss: 0.4368 - val_loss: 0.2449
# Epoch 18/150
# 1/1 [==============================] - 0s 479ms/step - loss: 0.2379 - val_loss: 0.0470
# Epoch 19/150
# 1/1 [==============================] - 0s 422ms/step - loss: 0.0439 - val_loss: 0.0070
# Epoch 20/150
# 1/1 [==============================] - 0s 499ms/step - loss: 0.0083 - val_loss: 0.1085
# Epoch 21/150
# 1/1 [==============================] - 0s 341ms/step - loss: 0.1133 - val_loss: 0.2162
# Epoch 22/150
# 1/1 [==============================] - 0s 311ms/step - loss: 0.2230 - val_loss: 0.2209
# Epoch 23/150
# 1/1 [==============================] - 0s 478ms/step - loss: 0.2277 - val_loss: 0.1280
# Epoch 24/150
# 1/1 [==============================] - 0s 316ms/step - loss: 0.1332 - val_loss: 0.0283
# Epoch 25/150
# 1/1 [==============================] - 0s 204ms/step - loss: 0.0308 - val_loss: 0.0021
# Epoch 26/150
# 1/1 [==============================] - 0s 223ms/step - loss: 0.0015 - val_loss: 0.0523
# Epoch 27/150
# 1/1 [==============================] - 0s 337ms/step - loss: 0.0491 - val_loss: 0.1153
# Epoch 28/150
# 1/1 [==============================] - 0s 277ms/step - loss: 0.1105 - val_loss: 0.1280
# Epoch 29/150
# 1/1 [==============================] - 0s 217ms/step - loss: 0.1229 - val_loss: 0.0829
# Epoch 30/150
# 1/1 [==============================] - 1s 551ms/step - loss: 0.0788 - val_loss: 0.0242
# Epoch 31/150
# 1/1 [==============================] - 0s 487ms/step - loss: 0.0220 - val_loss: 2.1734e-07
# Epoch 32/150
# 1/1 [==============================] - 0s 400ms/step - loss: 6.6892e-05 - val_loss: 0.0195
# Epoch 33/150
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0216 - val_loss: 0.0524
# Epoch 34/150
# 1/1 [==============================] - 0s 234ms/step - loss: 0.0558 - val_loss: 0.0628
# Epoch 35/150
# 1/1 [==============================] - 0s 249ms/step - loss: 0.0665 - val_loss: 0.0422
# Epoch 36/150
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0452 - val_loss: 0.0123
# Epoch 37/150
# 1/1 [==============================] - 0s 330ms/step - loss: 0.0139 - val_loss: 2.5782e-05
# Epoch 38/150
# 1/1 [==============================] - 0s 285ms/step - loss: 1.2816e-05 - val_loss: 0.0122
# Epoch 39/150
# 1/1 [==============================] - 0s 208ms/step - loss: 0.0107 - val_loss: 0.0323
# Epoch 40/150
# 1/1 [==============================] - 0s 225ms/step - loss: 0.0297 - val_loss: 0.0389
# Epoch 41/150
# 1/1 [==============================] - 0s 298ms/step - loss: 0.0361 - val_loss: 0.0266
# Epoch 42/150
# 1/1 [==============================] - 0s 331ms/step - loss: 0.0244 - val_loss: 0.0083
# Epoch 43/150
# 1/1 [==============================] - 0s 153ms/step - loss: 0.0071 - val_loss: 1.3507e-05
# Epoch 44/150
# 1/1 [==============================] - 0s 332ms/step - loss: 2.0681e-05 - val_loss: 0.0056
# Epoch 45/150
# 1/1 [==============================] - 0s 458ms/step - loss: 0.0067 - val_loss: 0.0153
# Epoch 46/150
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0172 - val_loss: 0.0176
# Epoch 47/150
# 1/1 [==============================] - 0s 369ms/step - loss: 0.0196 - val_loss: 0.0105
# Epoch 48/150
# 1/1 [==============================] - 0s 207ms/step - loss: 0.0120 - val_loss: 0.0020
# Epoch 49/150
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0027 - val_loss: 4.8602e-04
# Epoch 50/150
# 1/1 [==============================] - 0s 167ms/step - loss: 2.2934e-04 - val_loss: 0.0062
# Epoch 51/150
# 1/1 [==============================] - 0s 313ms/step - loss: 0.0051 - val_loss: 0.0120
# Epoch 52/150
# 1/1 [==============================] - 0s 338ms/step - loss: 0.0105 - val_loss: 0.0118
# Epoch 53/150
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0103 - val_loss: 0.0062
# Epoch 54/150
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0051 - val_loss: 9.3326e-04
# Epoch 55/150
# 1/1 [==============================] - 0s 142ms/step - loss: 5.5446e-04 - val_loss: 3.8827e-04
# Epoch 56/150
# 1/1 [==============================] - 0s 293ms/step - loss: 7.3122e-04 - val_loss: 0.0033
# Epoch 57/150
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0042 - val_loss: 0.0052
# Epoch 58/150
# 1/1 [==============================] - 0s 158ms/step - loss: 0.0063 - val_loss: 0.0039
# Epoch 59/150
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0048 - val_loss: 0.0010
# Epoch 60/150
# 1/1 [==============================] - 0s 197ms/step - loss: 0.0016 - val_loss: 4.8316e-05
# Epoch 61/150
# 1/1 [==============================] - 0s 152ms/step - loss: 8.4387e-06 - val_loss: 0.0018
# Epoch 62/150
# 1/1 [==============================] - 0s 147ms/step - loss: 0.0013 - val_loss: 0.0041
# Epoch 63/150
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0032 - val_loss: 0.0043
# Epoch 64/150
# 1/1 [==============================] - 0s 215ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 65/150
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0018 - val_loss: 4.3287e-04
# Epoch 66/150
# 1/1 [==============================] - 0s 318ms/step - loss: 1.9401e-04 - val_loss: 8.4346e-05
# Epoch 67/150
# 1/1 [==============================] - 0s 169ms/step - loss: 2.7620e-04 - val_loss: 9.7005e-04
# Epoch 68/150
# 1/1 [==============================] - 0s 324ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 69/150
# 1/1 [==============================] - 0s 453ms/step - loss: 0.0021 - val_loss: 9.4606e-04
# Epoch 70/150
# 1/1 [==============================] - 0s 423ms/step - loss: 0.0014 - val_loss: 1.2463e-04
# Epoch 71/150
# 1/1 [==============================] - 0s 457ms/step - loss: 3.4491e-04 - val_loss: 1.5917e-04
# Epoch 72/150
# 1/1 [==============================] - 0s 190ms/step - loss: 3.7928e-05 - val_loss: 0.0010
# Epoch 73/150
# 1/1 [==============================] - 0s 196ms/step - loss: 6.4294e-04 - val_loss: 0.0018
# Epoch 74/150
# 1/1 [==============================] - 0s 238ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 75/150
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0010 - val_loss: 6.4852e-04
# Epoch 76/150
# 1/1 [==============================] - 0s 267ms/step - loss: 3.4273e-04 - val_loss: 5.0455e-05
# Epoch 77/150
# 1/1 [==============================] - 0s 321ms/step - loss: 8.3916e-06 - val_loss: 9.0334e-05
# Epoch 78/150
# 1/1 [==============================] - 0s 189ms/step - loss: 2.8679e-04 - val_loss: 3.5381e-04
# Epoch 79/150
# 1/1 [==============================] - 0s 189ms/step - loss: 6.8391e-04 - val_loss: 3.3283e-04
# Epoch 80/150
# 1/1 [==============================] - 0s 222ms/step - loss: 6.5480e-04 - val_loss: 7.8780e-05
# Epoch 81/150
# 1/1 [==============================] - 0s 392ms/step - loss: 2.6620e-04 - val_loss: 2.7431e-05
# Epoch 82/150
# 1/1 [==============================] - 0s 170ms/step - loss: 1.2163e-05 - val_loss: 3.4988e-04
# Epoch 83/150
# 1/1 [==============================] - 0s 146ms/step - loss: 1.4119e-04 - val_loss: 7.1881e-04
# Epoch 84/150
# 1/1 [==============================] - 0s 427ms/step - loss: 3.9371e-04 - val_loss: 7.3656e-04
# Epoch 85/150
# 1/1 [==============================] - 1s 638ms/step - loss: 4.0674e-04 - val_loss: 4.1070e-04
# Epoch 86/150
# 1/1 [==============================] - 0s 316ms/step - loss: 1.7960e-04 - val_loss: 8.6731e-05
# Epoch 87/150
# 1/1 [==============================] - 1s 682ms/step - loss: 1.2930e-05 - val_loss: 1.9001e-06
# Epoch 88/150
# 1/1 [==============================] - 0s 285ms/step - loss: 8.1648e-05 - val_loss: 6.2832e-05
# Epoch 89/150
# 1/1 [==============================] - 1s 573ms/step - loss: 2.3662e-04 - val_loss: 6.8849e-05
# Epoch 90/150
# 1/1 [==============================] - 0s 176ms/step - loss: 2.4797e-04 - val_loss: 8.4503e-06
# Epoch 91/150
# 1/1 [==============================] - 0s 216ms/step - loss: 1.1015e-04 - val_loss: 3.2785e-05
# Epoch 92/150
# 1/1 [==============================] - 0s 245ms/step - loss: 1.0502e-05 - val_loss: 1.9837e-04
# Epoch 93/150
# 1/1 [==============================] - 0s 230ms/step - loss: 5.6045e-05 - val_loss: 3.6296e-04
# Epoch 94/150
# 1/1 [==============================] - 0s 144ms/step - loss: 1.4930e-04 - val_loss: 3.6306e-04
# Epoch 95/150
# 1/1 [==============================] - 0s 142ms/step - loss: 1.4936e-04 - val_loss: 2.1137e-04
# Epoch 96/150
# 1/1 [==============================] - 0s 178ms/step - loss: 6.2520e-05 - val_loss: 5.8329e-05
# Epoch 97/150
# 1/1 [==============================] - 0s 162ms/step - loss: 8.5934e-06 - val_loss: 1.4818e-06
# Epoch 98/150
# 1/1 [==============================] - 0s 195ms/step - loss: 4.3951e-05 - val_loss: 5.2236e-06
# Epoch 99/150
# 1/1 [==============================] - 0s 222ms/step - loss: 9.8001e-05 - val_loss: 3.1498e-06
# Epoch 100/150
# 1/1 [==============================] - 1s 732ms/step - loss: 8.8590e-05 - val_loss: 4.7835e-06
# Epoch 101/150
# 1/1 [==============================] - 0s 497ms/step - loss: 3.3324e-05 - val_loss: 5.9805e-05
# Epoch 102/150
# 1/1 [==============================] - 0s 166ms/step - loss: 8.6906e-06 - val_loss: 1.5707e-04
# Epoch 103/150
# 1/1 [==============================] - 0s 226ms/step - loss: 3.7025e-05 - val_loss: 2.1756e-04
# Epoch 104/150
# 1/1 [==============================] - 0s 238ms/step - loss: 6.5675e-05 - val_loss: 1.8869e-04
# Epoch 105/150
# 1/1 [==============================] - 0s 225ms/step - loss: 5.1357e-05 - val_loss: 1.0386e-04
# Epoch 106/150
# 1/1 [==============================] - 0s 254ms/step - loss: 1.7446e-05 - val_loss: 3.3310e-05
# Epoch 107/150
# 1/1 [==============================] - 0s 146ms/step - loss: 1.0371e-05 - val_loss: 5.5003e-06
# Epoch 108/150
# 1/1 [==============================] - 0s 239ms/step - loss: 3.1770e-05 - val_loss: 1.4732e-06
# Epoch 109/150
# 1/1 [==============================] - 0s 338ms/step - loss: 4.3991e-05 - val_loss: 6.9191e-06
# Epoch 110/150
# 1/1 [==============================] - 0s 178ms/step - loss: 2.9091e-05 - val_loss: 3.3420e-05
# Epoch 111/150
# 1/1 [==============================] - 0s 237ms/step - loss: 1.0345e-05 - val_loss: 8.4788e-05
# Epoch 112/150
# 1/1 [==============================] - 0s 255ms/step - loss: 1.2494e-05 - val_loss: 1.3147e-04
# Epoch 113/150
# 1/1 [==============================] - 0s 192ms/step - loss: 2.6748e-05 - val_loss: 1.3741e-04
# Epoch 114/150
# 1/1 [==============================] - 0s 230ms/step - loss: 2.9008e-05 - val_loss: 1.0106e-04
# Epoch 115/150
# 1/1 [==============================] - 0s 224ms/step - loss: 1.6631e-05 - val_loss: 5.3800e-05
# Epoch 116/150
# 1/1 [==============================] - 0s 362ms/step - loss: 8.4088e-06 - val_loss: 2.3164e-05
# Epoch 117/150
# 1/1 [==============================] - 0s 441ms/step - loss: 1.3993e-05 - val_loss: 1.2517e-05
# Epoch 118/150
# 1/1 [==============================] - 0s 343ms/step - loss: 2.1657e-05 - val_loss: 1.5511e-05
# Epoch 119/150
# 1/1 [==============================] - 1s 579ms/step - loss: 1.8900e-05 - val_loss: 3.2365e-05
# Epoch 120/150
# 1/1 [==============================] - 0s 330ms/step - loss: 1.0611e-05 - val_loss: 6.2626e-05
# Epoch 121/150
# 1/1 [==============================] - 0s 348ms/step - loss: 8.9222e-06 - val_loss: 9.2312e-05
# Epoch 122/150
# 1/1 [==============================] - 1s 514ms/step - loss: 1.4276e-05 - val_loss: 1.0173e-04
# Epoch 123/150
# 1/1 [==============================] - 0s 285ms/step - loss: 1.6826e-05 - val_loss: 8.5605e-05
# Epoch 124/150
# 1/1 [==============================] - 0s 298ms/step - loss: 1.2675e-05 - val_loss: 5.7632e-05
# Epoch 125/150
# 1/1 [==============================] - 1s 522ms/step - loss: 8.5543e-06 - val_loss: 3.4931e-05
# Epoch 126/150
# 1/1 [==============================] - 0s 327ms/step - loss: 1.0000e-05 - val_loss: 2.4518e-05
# Epoch 127/150
# 1/1 [==============================] - 0s 446ms/step - loss: 1.3356e-05 - val_loss: 2.5739e-05
# Epoch 128/150
# 1/1 [==============================] - 1s 675ms/step - loss: 1.2827e-05 - val_loss: 3.7477e-05
# Epoch 129/150
# 1/1 [==============================] - 0s 260ms/step - loss: 9.5071e-06 - val_loss: 5.6892e-05
# Epoch 130/150
# 1/1 [==============================] - 0s 262ms/step - loss: 8.5164e-06 - val_loss: 7.5074e-05
# Epoch 131/150
# 1/1 [==============================] - 0s 214ms/step - loss: 1.0587e-05 - val_loss: 8.1169e-05
# Epoch 132/150
# 1/1 [==============================] - 0s 368ms/step - loss: 1.1729e-05 - val_loss: 7.2139e-05
# Epoch 133/150
# 1/1 [==============================] - 0s 349ms/step - loss: 1.0109e-05 - val_loss: 5.5222e-05
# Epoch 134/150
# 1/1 [==============================] - 0s 437ms/step - loss: 8.4481e-06 - val_loss: 4.0410e-05
# Epoch 135/150
# 1/1 [==============================] - 0s 385ms/step - loss: 9.0643e-06 - val_loss: 3.3220e-05
# Epoch 136/150
# 1/1 [==============================] - 0s 331ms/step - loss: 1.0393e-05 - val_loss: 3.4565e-05
# Epoch 137/150
# 1/1 [==============================] - 0s 409ms/step - loss: 1.0079e-05 - val_loss: 4.3358e-05
# Epoch 138/150
# 1/1 [==============================] - 0s 299ms/step - loss: 8.7408e-06 - val_loss: 5.6222e-05
# Epoch 139/150
# 1/1 [==============================] - 0s 393ms/step - loss: 8.4861e-06 - val_loss: 6.6846e-05
# Epoch 140/150
# 1/1 [==============================] - 1s 607ms/step - loss: 9.3753e-06 - val_loss: 6.9284e-05
# Epoch 141/150
# 1/1 [==============================] - 1s 708ms/step - loss: 9.6911e-06 - val_loss: 6.2747e-05
# Epoch 142/150
# 1/1 [==============================] - 0s 432ms/step - loss: 8.9334e-06 - val_loss: 5.1973e-05
# Epoch 143/150
# 1/1 [==============================] - 1s 668ms/step - loss: 8.3863e-06 - val_loss: 4.2937e-05
# Epoch 144/150
# 1/1 [==============================] - 0s 285ms/step - loss: 8.7799e-06 - val_loss: 3.9157e-05
# Epoch 145/150
# 1/1 [==============================] - 0s 300ms/step - loss: 9.2382e-06 - val_loss: 4.1349e-05
# Epoch 146/150
# 1/1 [==============================] - 0s 477ms/step - loss: 8.9491e-06 - val_loss: 4.8228e-05
# Epoch 147/150
# 1/1 [==============================] - 0s 370ms/step - loss: 8.4411e-06 - val_loss: 5.6592e-05
# Epoch 148/150
# 1/1 [==============================] - 0s 387ms/step - loss: 8.5021e-06 - val_loss: 6.2099e-05
# Epoch 149/150
# 1/1 [==============================] - 0s 318ms/step - loss: 8.8747e-06 - val_loss: 6.1871e-05
# Epoch 150/150
# 1/1 [==============================] - 0s 175ms/step - loss: 8.8545e-06 - val_loss: 5.6559e-05
# MSE:  0.00032880824530946256
# Time:  90.46203210501699
